# %%
import numpy as np
import pandas as pd
data=pd.read_csv("train_data.csv")

# %%
data
# Out:
#                 Make                Model  Year  \
# 0                GMC              Terrain  2017
# 1              Scion                   xD  2013
# 2            Hyundai             Veloster  2016
# 3                GMC  Sierra 1500 Classic  2007
# 4              Mazda             B-Series  2001
# 5             Suzuki                  XL7  2007
# 6              Mazda       B-Series Truck  2009
# 7              Lexus               LS 460  2016
# 8          Chevrolet             Corvette  2016
# 9         Volkswagen   Beetle Convertible  2016
# 10               GMC          Sierra 1500  2015
# 11      Aston Martin                  DBS  2012
# 12           Pontiac           Grand Prix  2006
# 13           Porsche              Boxster  2016
# 14             Dodge               Dakota  2010
# 15             Lexus               GX 470  2007
# 16        Volkswagen            Jetta GLI  2014
# 17               GMC           S-15 Jimmy  1991
# ...

# %%
x_train=data.iloc[0:10721,0:16]

x_train.head()
# Out:
#       Make                Model  Year  Engine Fuel Type  Engine HP  \
# 0      GMC              Terrain  2017  regular unleaded      182.0
# 1    Scion                   xD  2013  regular unleaded      128.0
# 2  Hyundai             Veloster  2016  regular unleaded      132.0
# 3      GMC  Sierra 1500 Classic  2007  regular unleaded      285.0
# 4    Mazda             B-Series  2001  regular unleaded      150.0
#
#    Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0               4.0         AUTOMATIC  front wheel drive              4.0
# 1               4.0         AUTOMATIC  front wheel drive              4.0
# 2               4.0  AUTOMATED_MANUAL  front wheel drive              3.0
# 3               8.0         AUTOMATIC   four wheel drive              2.0
# 4               6.0            MANUAL   rear wheel drive              2.0
#
#   Market Category Vehicle Size        Vehicle Style  highway MPG  city mpg  \
# ...

# %%
x_train.drop(["Market Category"], axis = 1, inplace = True)

# %%
x_train
# Out:
#                 Make                Model  Year  \
# 0                GMC              Terrain  2017
# 1              Scion                   xD  2013
# 2            Hyundai             Veloster  2016
# 3                GMC  Sierra 1500 Classic  2007
# 4              Mazda             B-Series  2001
# 5             Suzuki                  XL7  2007
# 6              Mazda       B-Series Truck  2009
# 7              Lexus               LS 460  2016
# 8          Chevrolet             Corvette  2016
# 9         Volkswagen   Beetle Convertible  2016
# 10               GMC          Sierra 1500  2015
# 11      Aston Martin                  DBS  2012
# 12           Pontiac           Grand Prix  2006
# 13           Porsche              Boxster  2016
# 14             Dodge               Dakota  2010
# 15             Lexus               GX 470  2007
# 16        Volkswagen            Jetta GLI  2014
# 17               GMC           S-15 Jimmy  1991
# ...

# %%
x_train['Transmission Type'].replace({'AUTOMATIC':1, 'AUTOMATED_MANUAL':2, 'MANUAL':3, 'DIRECT_DRIVE':4,
       'UNKNOWN':5},inplace=True)
x_train['Driven_Wheels'].replace({'front wheel drive':1, 'four wheel drive':2, 'rear wheel drive':3,
       'all wheel drive':4},inplace=True)
x_train['Vehicle Size'].replace({'Compact':1, 'Large':3, 'Midsize':2},inplace=True)
x_train['Make'].replace({'GMC':1, 'Scion':2, 'Hyundai':3, 'Mazda':4, 'Suzuki':5, 'Lexus':6, 'Chevrolet':7,
       'Volkswagen':8, 'Aston Martin':9, 'Pontiac':10, 'Porsche':11, 'Dodge':12,
       'Toyota':13, 'Nissan':14, 'Ford':15, 'Mercedes-Benz':16, 'Infiniti':17, 'Kia':18,
       'Audi':19, 'Honda':20, 'Maserati':21, 'Maybach':22, 'Volvo':23, 'BMW':24, 'Cadillac':25,
       'Mitsubishi':26, 'Oldsmobile':27, 'Acura':28, 'Bentley':29, 'Lamborghini':30,
       'FIAT':31, 'Chrysler':32, 'Subaru':33, 'Saab':34, 'Land Rover':35, 'Lincoln':36,
       'Buick':37, 'HUMMER':38, 'Tesla':39, 'McLaren':40, 'Plymouth':41, 'Bugatti':42,
       'Rolls-Royce':43, 'Ferrari':44, 'Alfa Romeo':45, 'Lotus':46, 'Spyker':47,
       'Genesis':48},inplace=True)
x_train.drop(["Model"], axis = 1, inplace = True)
x_train['Engine Fuel Type'].replace({'regular unleaded':1, 'premium unleaded (required)':2,
       'premium unleaded (recommended)':3, 'flex-fuel (unleaded/E85)':4,
       'diesel':5, 'flex-fuel (premium unleaded required/E85)':6, 'electric':7,
       'flex-fuel (unleaded/natural gas)':8,
       'flex-fuel (premium unleaded recommended/E85)':9, 'nan':10, 'natural gas':11},inplace=True)
x_train['Vehicle Style'].replace({'4dr SUV':1, '4dr Hatchback':2, '2dr Hatchback':3, 'Regular Cab Pickup':4,
       'Extended Cab Pickup':5, 'Sedan':6, 'Coupe':7, 'Convertible':8,
       'Crew Cab Pickup':9, '2dr SUV':10, 'Passenger Van':11, 'Wagon':12,
       'Cargo Minivan':13, 'Cargo Van':14, 'Passenger Minivan':15,
       'Convertible SUV':16},inplace=True)
x_train.replace([np.inf,-np.inf], np.nan)
x_train.fillna(x_train.MSRP.median(),inplace=True)

# %%
x_train
# Out:
#        Make  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0         1  2017               1.0      182.0               4.0
# 1         2  2013               1.0      128.0               4.0
# 2         3  2016               1.0      132.0               4.0
# 3         1  2007               1.0      285.0               8.0
# 4         4  2001               1.0      150.0               6.0
# 5         5  2007               1.0      252.0               6.0
# 6         4  2009               1.0      143.0               4.0
# 7         6  2016               2.0      386.0               8.0
# 8         7  2016               2.0      650.0               8.0
# 9         8  2016               3.0      210.0               4.0
# 10        1  2015               1.0      355.0               8.0
# 11        9  2012               2.0      510.0              12.0
# 12       10  2006               1.0      260.0               6.0
# ...

# %%
y_train=x_train['MSRP']


y_train
# Out:
# 0         27300
# 1         16545
# 2         19100
# 3         26295
# 4         17545
# 5         24599
# 6         16060
# 7         78820
# 8         79400
# 9         29790
# 10        53115
# 11       295987
# 12        24330
# 13        52100
# 14        27880
# 15        46635
# 16        27455
# 17         2000
# 18        27395
# 19        42455
# 20        33475
# 21        32690
# 22        35920
# 23        33065
# 24        17680
# 25        17250
# 26        47270
# 27        29100
# 28        43700
# 29         2178
#           ...
# 10691     26920
# 10692     37405
# 10693     23865
# 10694     40275
# 10695     15990
# 10696     16499
# 10697     53695
# 10698     26950
# 10699     44280
# 10700     33295
# 10701     11045
# 10702     46800
# 10703     24815
# 10704      2767
# 10705     28020
# 10706     60450
# 10707     48450
# 10708     42700
# 10709    275000
# 10710    203295
# 10711     29615
# 10712     21600
# 10713     62900
# 10714     39080
# ...

# %%
x_train.drop(["MSRP"], axis = 1, inplace = True)

# %%
x_train
# Out:
#        Make  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0         1  2017               1.0      182.0               4.0
# 1         2  2013               1.0      128.0               4.0
# 2         3  2016               1.0      132.0               4.0
# 3         1  2007               1.0      285.0               8.0
# 4         4  2001               1.0      150.0               6.0
# 5         5  2007               1.0      252.0               6.0
# 6         4  2009               1.0      143.0               4.0
# 7         6  2016               2.0      386.0               8.0
# 8         7  2016               2.0      650.0               8.0
# 9         8  2016               3.0      210.0               4.0
# 10        1  2015               1.0      355.0               8.0
# 11        9  2012               2.0      510.0              12.0
# 12       10  2006               1.0      260.0               6.0
# ...

# %%
y_train
# Out:
# 0         27300
# 1         16545
# 2         19100
# 3         26295
# 4         17545
# 5         24599
# 6         16060
# 7         78820
# 8         79400
# 9         29790
# 10        53115
# 11       295987
# 12        24330
# 13        52100
# 14        27880
# 15        46635
# 16        27455
# 17         2000
# 18        27395
# 19        42455
# 20        33475
# 21        32690
# 22        35920
# 23        33065
# 24        17680
# 25        17250
# 26        47270
# 27        29100
# 28        43700
# 29         2178
#           ...
# 10691     26920
# 10692     37405
# 10693     23865
# 10694     40275
# 10695     15990
# 10696     16499
# 10697     53695
# 10698     26950
# 10699     44280
# 10700     33295
# 10701     11045
# 10702     46800
# 10703     24815
# 10704      2767
# 10705     28020
# 10706     60450
# 10707     48450
# 10708     42700
# 10709    275000
# 10710    203295
# 10711     29615
# 10712     21600
# 10713     62900
# 10714     39080
# ...

# %%
data_test=pd.read_csv("test_data.csv")

# %%
data_test
# Out:
#               Make               Model  Year                Engine Fuel Type  \
# 0            Acura                 TLX  2017  premium unleaded (recommended)
# 1        Chevrolet               Sonic  2017                regular unleaded
# 2     Aston Martin        V12 Vanquish  2005     premium unleaded (required)
# 3             Ford      E-Series Wagon  2014        flex-fuel (unleaded/E85)
# 4             Audi                  S5  2016     premium unleaded (required)
# 5             Ford               E-150  1996                regular unleaded
# 6       Land Rover         Range Rover  2016  premium unleaded (recommended)
# 7           Toyota                ECHO  2003                regular unleaded
# 8          Pontiac                  G6  2009                regular unleaded
# 9       Volkswagen                 GTI  2012  premium unleaded (recommended)
# 10           Acura                 MDX  2017  premium unleaded (recommended)
# ...

# %%
x_test=pd.read_csv("test_data.csv")
x_test.drop(["Market Category"], axis = 1, inplace = True)

# %%
x_test=x_test.iloc[0:1192,0:15]
data_test
# Out:
#               Make               Model  Year                Engine Fuel Type  \
# 0            Acura                 TLX  2017  premium unleaded (recommended)
# 1        Chevrolet               Sonic  2017                regular unleaded
# 2     Aston Martin        V12 Vanquish  2005     premium unleaded (required)
# 3             Ford      E-Series Wagon  2014        flex-fuel (unleaded/E85)
# 4             Audi                  S5  2016     premium unleaded (required)
# 5             Ford               E-150  1996                regular unleaded
# 6       Land Rover         Range Rover  2016  premium unleaded (recommended)
# 7           Toyota                ECHO  2003                regular unleaded
# 8          Pontiac                  G6  2009                regular unleaded
# 9       Volkswagen                 GTI  2012  premium unleaded (recommended)
# 10           Acura                 MDX  2017  premium unleaded (recommended)
# ...

# %%
x_test
# Out:
#               Make               Model  Year                Engine Fuel Type  \
# 0            Acura                 TLX  2017  premium unleaded (recommended)
# 1        Chevrolet               Sonic  2017                regular unleaded
# 2     Aston Martin        V12 Vanquish  2005     premium unleaded (required)
# 3             Ford      E-Series Wagon  2014        flex-fuel (unleaded/E85)
# 4             Audi                  S5  2016     premium unleaded (required)
# 5             Ford               E-150  1996                regular unleaded
# 6       Land Rover         Range Rover  2016  premium unleaded (recommended)
# 7           Toyota                ECHO  2003                regular unleaded
# 8          Pontiac                  G6  2009                regular unleaded
# 9       Volkswagen                 GTI  2012  premium unleaded (recommended)
# 10           Acura                 MDX  2017  premium unleaded (recommended)
# ...

# %%
x_test['Transmission Type'].replace({'AUTOMATIC':1, 'AUTOMATED_MANUAL':2, 'MANUAL':3, 'DIRECT_DRIVE':4,
       'UNKNOWN':5},inplace=True)
x_test['Driven_Wheels'].replace({'front wheel drive':1, 'four wheel drive':2, 'rear wheel drive':3,
       'all wheel drive':4},inplace=True)
x_test['Vehicle Size'].replace({'Compact':1, 'Large':3, 'Midsize':2},inplace=True)
x_test['Make'].replace({'GMC':1, 'Scion':2, 'Hyundai':3, 'Mazda':4, 'Suzuki':5, 'Lexus':6, 'Chevrolet':7,
       'Volkswagen':8, 'Aston Martin':9, 'Pontiac':10, 'Porsche':11, 'Dodge':12,
       'Toyota':13, 'Nissan':14, 'Ford':15, 'Mercedes-Benz':16, 'Infiniti':17, 'Kia':18,
       'Audi':19, 'Honda':20, 'Maserati':21, 'Maybach':22, 'Volvo':23, 'BMW':24, 'Cadillac':25,
       'Mitsubishi':26, 'Oldsmobile':27, 'Acura':28, 'Bentley':29, 'Lamborghini':30,
       'FIAT':31, 'Chrysler':32, 'Subaru':33, 'Saab':34, 'Land Rover':35, 'Lincoln':36,
       'Buick':37, 'HUMMER':38, 'Tesla':39, 'McLaren':40, 'Plymouth':41, 'Bugatti':42,
       'Rolls-Royce':43, 'Ferrari':44, 'Alfa Romeo':45, 'Lotus':46, 'Spyker':47,
       'Genesis':48},inplace=True)
x_test.drop(["Model"], axis = 1, inplace = True)
x_test['Engine Fuel Type'].replace({'regular unleaded':1, 'premium unleaded (required)':2,
       'premium unleaded (recommended)':3, 'flex-fuel (unleaded/E85)':4,
       'diesel':5, 'flex-fuel (premium unleaded required/E85)':6, 'electric':7,
       'flex-fuel (unleaded/natural gas)':8,
       'flex-fuel (premium unleaded recommended/E85)':9, 'nan':10, 'natural gas':11},inplace=True)
x_test['Vehicle Style'].replace({'4dr SUV':1, '4dr Hatchback':2, '2dr Hatchback':3, 'Regular Cab Pickup':4,
       'Extended Cab Pickup':5, 'Sedan':6, 'Coupe':7, 'Convertible':8,
       'Crew Cab Pickup':9, '2dr SUV':10, 'Passenger Van':11, 'Wagon':12,
       'Cargo Minivan':13, 'Cargo Van':14, 'Passenger Minivan':15,
       'Convertible SUV':16},inplace=True)

# %%
x_test
# Out:
#       Make  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0       28  2017                 3      290.0               6.0
# 1        7  2017                 1      138.0               4.0
# 2        9  2005                 2      460.0              12.0
# 3       15  2014                 4      255.0               8.0
# 4       19  2016                 2      333.0               6.0
# 5       15  1996                 1      145.0               6.0
# 6       35  2016                 3      510.0               8.0
# 7       13  2003                 1      108.0               4.0
# 8       10  2009                 1      164.0               4.0
# 9        8  2012                 3      200.0               4.0
# 10      28  2017                 3      290.0               6.0
# 11       6  2000                 1      300.0               8.0
# 12       1  1991                 1      150.0               6.0
# 13       8  2012                 3      200.0               4.0
# ...

# %%
x_test=x_test.iloc[0:1192,0:13]
x_test.replace([np.inf,-np.inf], np.nan)
# Out:
#       Make  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0       28  2017                 3      290.0               6.0
# 1        7  2017                 1      138.0               4.0
# 2        9  2005                 2      460.0              12.0
# 3       15  2014                 4      255.0               8.0
# 4       19  2016                 2      333.0               6.0
# 5       15  1996                 1      145.0               6.0
# 6       35  2016                 3      510.0               8.0
# 7       13  2003                 1      108.0               4.0
# 8       10  2009                 1      164.0               4.0
# 9        8  2012                 3      200.0               4.0
# 10      28  2017                 3      290.0               6.0
# 11       6  2000                 1      300.0               8.0
# 12       1  1991                 1      150.0               6.0
# 13       8  2012                 3      200.0               4.0
# ...

# %%
x_test.fillna(x_test['Engine HP'].median(),inplace=True)
x_test.fillna(x_test['Engine Cylinders'].median(),inplace=True)
x_test.fillna(x_test['Number of Doors'].median(),inplace=True)

x_test
# Out:
#       Make  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0       28  2017                 3      290.0               6.0
# 1        7  2017                 1      138.0               4.0
# 2        9  2005                 2      460.0              12.0
# 3       15  2014                 4      255.0               8.0
# 4       19  2016                 2      333.0               6.0
# 5       15  1996                 1      145.0               6.0
# 6       35  2016                 3      510.0               8.0
# 7       13  2003                 1      108.0               4.0
# 8       10  2009                 1      164.0               4.0
# 9        8  2012                 3      200.0               4.0
# 10      28  2017                 3      290.0               6.0
# 11       6  2000                 1      300.0               8.0
# 12       1  1991                 1      150.0               6.0
# 13       8  2012                 3      200.0               4.0
# ...

# %%
import xgboost as xgb
import csv as csv
from xgboost import plot_importance
from matplotlib import pyplot
from sklearn.model_selection import cross_val_score,KFold
from sklearn.cross_validation import  train_test_split
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
from sklearn.grid_search import GridSearchCV   #Perforing grid search
from scipy.stats import skew
from collections import OrderedDict
from sklearn.model_selection import train_test_split

# %%
best_xgb_model = xgb.XGBRegressor(objective ='reg:linear',colsample_bytree=0.4,
                 gamma=0,                 
                 learning_rate=0.07,
                 max_depth=5,
                 min_child_weight=1.5,
                 n_estimators=10000,                                                                    
                 reg_alpha=0.75,
                 reg_lambda=0.45,
                 subsample=0.7,
                 seed=42)
best_xgb_model.fit(x_train,y_train)
# Out:
# /home/poc/anaconda3/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /home/poc/anaconda3/lib/python3.6/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# [19:41:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=0.4, gamma=0,
#        importance_type='gain', learning_rate=0.07, max_delta_step=0,
#        max_depth=5, min_child_weight=1.5, missing=None, n_estimators=10000,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0.75, reg_lambda=0.45, scale_pos_weight=1, seed=42,
# ...

# %%
predx=best_xgb_model.predict(x_test)

# %%
predx
# Out:
# array([ 45778.68 ,  19758.123, 266836.   , ...,  22351.297,  30563.363,
#         32020.41 ], dtype=float32)

# %%
data_test.MSRP=predx

# %%
data_test
# Out:
#               Make               Model  Year                Engine Fuel Type  \
# 0            Acura                 TLX  2017  premium unleaded (recommended)
# 1        Chevrolet               Sonic  2017                regular unleaded
# 2     Aston Martin        V12 Vanquish  2005     premium unleaded (required)
# 3             Ford      E-Series Wagon  2014        flex-fuel (unleaded/E85)
# 4             Audi                  S5  2016     premium unleaded (required)
# 5             Ford               E-150  1996                regular unleaded
# 6       Land Rover         Range Rover  2016  premium unleaded (recommended)
# 7           Toyota                ECHO  2003                regular unleaded
# 8          Pontiac                  G6  2009                regular unleaded
# 9       Volkswagen                 GTI  2012  premium unleaded (recommended)
# 10           Acura                 MDX  2017  premium unleaded (recommended)
# ...

# %%
data_test.to_csv('test_data_submission.csv')
